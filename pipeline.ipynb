# %%
import pandas as pd
import numpy as np

from monotonic import *

# %%
pd.options.display.max_rows = 6

# %% [markdown]
# ### 1. Read data from file

# %%
data = pd.read_excel('data/bank.xlsx')
data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# ### 2. Statistics collection from 'numeric' and 'categorical' feature

# %%
Y = (data['y'] == 'yes').astype(int).values
X_num = data['balance'].values
X_cat = data['job'].values
example_num = create_stats(X_num, Y)
example_cat = create_stats(X_cat, Y, 'categorical')

# %%
example_num
# Out:
#    VAR_NAME               BUCKET  MIN_VALUE  MAX_VALUE  COUNT  EVENT  \
# 0       VAR  (-3313.001, -162.0]    -3313.0     -162.0    227     25
# 1       VAR        (-162.0, 0.0]     -154.0        0.0    496     35
# 2       VAR          (0.0, 23.0]        1.0       23.0    190     20
# ..      ...                  ...        ...        ...    ...    ...
# 17      VAR     (3913.0, 6102.0]     3921.0     6102.0    226     38
# 18      VAR    (6102.0, 71188.0]     6145.0    71188.0    226     20
# 19      VAR                  NaN        NaN        NaN      0      0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.110132       202        0.889868    0.047985         0.05050
# 1     0.070565       461        0.929435    0.067179         0.11525
# 2     0.105263       170        0.894737    0.038388         0.04250
# ..         ...       ...             ...         ...             ...
# 17    0.168142       188        0.831858    0.072937         0.04700
# 18    0.088496       206        0.911504    0.038388         0.05150
# 19    0.000000         0        0.000000    0.000000         0.00000
#
#          WOE        IV
# 0  -0.051091  0.133798
# 1  -0.539744  0.133798
# 2  -0.101764  0.133798
# ..       ...       ...
# 17  0.439436  0.133798
# 18 -0.293838  0.133798
# 19  0.000000  0.133798
#
# [20 rows x 13 columns]

# %%
example_cat
# Out:
#    VAR_NAME        BUCKET     MIN_VALUE     MAX_VALUE  COUNT  EVENT  \
# 0       VAR        admin.        admin.        admin.    478     58
# 1       VAR   blue-collar   blue-collar   blue-collar    946     69
# 2       VAR  entrepreneur  entrepreneur  entrepreneur    168     15
# ..      ...           ...           ...           ...    ...    ...
# 10      VAR    unemployed    unemployed    unemployed    128     13
# 11      VAR       unknown       unknown       unknown     38      7
# 12      VAR           NaN           NaN           NaN      0      0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.121339       420        0.878661    0.111324         0.10500
# 1     0.072939       877        0.927061    0.132438         0.21925
# 2     0.089286       153        0.910714    0.028791         0.03825
# ..         ...       ...             ...         ...             ...
# 10    0.101562       115        0.898437    0.024952         0.02875
# 11    0.184211        31        0.815789    0.013436         0.00775
# 12    0.000000         0        0.000000    0.000000         0.00000
#
#          WOE        IV
# 0   0.058487  0.132516
# 1  -0.504098  0.132516
# 2  -0.284080  0.132516
# ..       ...       ...
# 10 -0.141678  0.132516
# 11  0.550168  0.132516
# 12  0.000000  0.132516
#
# [13 rows x 13 columns]

# %% [markdown]
# ### 3. Make 'numeric' data monotonic by WOE

# %%
monotonic_example_num = make_monotonic(example_num)
monotonic_example_num
# Out:
#    VAR_NAME             BUCKET  MIN_VALUE  MAX_VALUE  COUNT  EVENT  \
# 0       VAR  (-3313.001, 69.0]    -3313.0       69.0   1133     94
# 1       VAR      (69.0, 194.0]       70.0      194.0    451     40
# 2       VAR     (194.0, 444.0]      195.0      444.0    677     66
# ..      ...                ...        ...        ...    ...    ...
# 4       VAR    (894.0, 1957.0]      895.0     1957.0    677     92
# 5       VAR  (1957.0, 71188.0]     1959.0    71188.0    904    144
# 6       VAR                NaN        NaN        NaN      0      0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.082966      1039             1.0    0.180422         0.25975
# 1     0.088692       411             1.0    0.076775         0.10275
# 2     0.097489       611             1.0    0.126679         0.15275
# ..         ...       ...             ...         ...             ...
# 4     0.135894       585             1.0    0.176583         0.14625
# 5     0.159292       760             1.0    0.276392         0.19000
# 6     0.000000         0             0.0    0.000000         0.00000
#
#          WOE        IV
# 0  -0.364418  0.080831
# 1  -0.291411  0.080831
# 2  -0.187141  0.080831
# ..       ...       ...
# 4   0.188475  0.080831
# 5   0.374793  0.080831
# 6   0.000000  0.080831
#
# [7 rows x 13 columns]

# %% [markdown]
# ### 4. Use Algotithm of monotonic optimal binning for 'numeric' feature

# %%
optimal_example_num = monotone_optimal_binning(X_num, Y)
optimal_example_num
# Out:
#   VAR_NAME                  BUCKET  MIN_VALUE  MAX_VALUE  COUNT  EVENT  \
# 0      VAR  (-1000000000.0, 444.0]    -3313.0      444.0   2261    200
# 1      VAR   (444.0, 1000000000.0]      445.0    71188.0   2260    321
# 2      VAR                     NaN        NaN        NaN      0      0
#
#    EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT       WOE  \
# 0    0.088456      2061             1.0    0.383877         0.51525 -0.294329
# 1    0.142035      1939             1.0    0.616123         0.48475  0.239813
# 2    0.000000         0             0.0    0.000000         0.00000  0.000000
#
#          IV
# 0  0.070172
# 1  0.070172
# 2  0.070172

# %% [markdown]
# ### 5. Apply previous steps for each feature

# %%
full_stats, iv_values = create_bins_df(data)
full_stats
# Out:
#     VAR_NAME                 BUCKET MIN_VALUE MAX_VALUE  COUNT  EVENT  \
# 0        age  (-1000000000.0, 59.0]        19        59   4347    466
# 1        age   (59.0, 1000000000.0]        60        87    174     55
# 2        age                    NaN       NaN       NaN      0      0
# ..       ...                    ...       ...       ...    ...    ...
# 72  poutcome                success   success   success    129     83
# 73  poutcome                unknown   unknown   unknown   3705    337
# 74  poutcome                    NaN       NaN       NaN      0      0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.107200      3881        1.000000    0.894434         0.97025
# 1     0.316092       119        0.683908    0.105566         0.02975
# 2     0.000000         0        0.000000    0.000000         0.00000
# ..         ...       ...             ...         ...             ...
# 72    0.643411        46        0.356589    0.159309         0.01150
# 73    0.090958      3368        0.909042    0.646833         0.84200
# 74    0.000000         0        0.000000    0.000000         0.00000
#
#          WOE        IV
# 0  -0.081363  0.102189
# 1   1.266485  0.102189
# 2   0.000000  0.102189
# ..       ...       ...
# 72  2.628418  0.461878
# 73 -0.263691  0.461878
# 74  0.000000  0.461878
#
# [75 rows x 13 columns]

# %%
iv_values
# Out:
#     VAR_NAME            IV
# 0        age  1.021887e-01
# 1    balance  7.017170e-02
# 2   campaign  2.786846e-18
# ..       ...           ...
# 13     pdays  6.077975e-02
# 14  poutcome  4.618775e-01
# 15  previous  1.770802e-01
#
# [16 rows x 2 columns]

# %% [markdown]
# ### 6. Cut of by Information Values

# %%
full_stats_cut, use_name_iv = cut_off_iv(full_stats, iv_values)
full_stats_cut
# Out:
#     VAR_NAME                 BUCKET MIN_VALUE MAX_VALUE  COUNT  EVENT  \
# 0        age  (-1000000000.0, 59.0]        19        59   4347    466
# 1        age   (59.0, 1000000000.0]        60        87    174     55
# 2        age                    NaN       NaN       NaN      0      0
# ..       ...                    ...       ...       ...    ...    ...
# 72  poutcome                success   success   success    129     83
# 73  poutcome                unknown   unknown   unknown   3705    337
# 74  poutcome                    NaN       NaN       NaN      0      0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.107200      3881        1.000000    0.894434         0.97025
# 1     0.316092       119        0.683908    0.105566         0.02975
# 2     0.000000         0        0.000000    0.000000         0.00000
# ..         ...       ...             ...         ...             ...
# 72    0.643411        46        0.356589    0.159309         0.01150
# 73    0.090958      3368        0.909042    0.646833         0.84200
# 74    0.000000         0        0.000000    0.000000         0.00000
#
#          WOE        IV
# 0  -0.081363  0.102189
# 1   1.266485  0.102189
# 2   0.000000  0.102189
# ..       ...       ...
# 72  2.628418  0.461878
# 73 -0.263691  0.461878
# 74  0.000000  0.461878
#
# [67 rows x 13 columns]

# %%
use_name_iv
# Out:
# array(['age', 'balance', 'contact', 'duration', 'education', 'housing',
#        'job', 'loan', 'marital', 'month', 'pdays', 'poutcome', 'previous'],
#       dtype=object)

# %% [markdown]
# ### 7. Replace all features by WOE

# %%
data_woe = replace_by_woe_naive(data, full_stats_cut, use_name_iv)
data_woe
# Out:
#        WOE_age  WOE_balance  WOE_contact  WOE_duration  WOE_education  \
# 0    -0.081363     0.239813     0.252971     -1.807909      -0.222811
# 1    -0.081363     0.239813     0.252971      0.152049      -0.091389
# 2    -0.081363     0.239813     0.252971     -0.934434       0.247403
# ...        ...          ...          ...           ...            ...
# 4518 -0.081363    -0.294329     0.252971     -0.934434      -0.091389
# 4519 -0.081363     0.239813     0.252971     -1.807909      -0.091389
# 4520 -0.081363     0.239813     0.252971      0.152049       0.247403
#
#       WOE_housing   WOE_job  WOE_loan  WOE_marital  WOE_month  WOE_pdays  \
# 0        0.330234 -0.141678  0.090598    -0.169697   1.887938  -0.117128
# 1       -0.325551 -0.261647 -0.674385    -0.169697  -0.603057   0.521549
# 2       -0.325551  0.182478  0.090598     0.219950   0.595584   0.521549
# ...           ...       ...       ...          ...        ...        ...
# 4518     0.330234 -0.072278  0.090598    -0.169697   0.090582  -0.117128
# 4519     0.330234 -0.504098  0.090598    -0.169697   0.460942   0.521549
# 4520    -0.325551 -0.284080 -0.674385     0.219950   0.595584   0.521549
#
#       WOE_poutcome  WOE_previous  target
# 0        -0.263691     -0.190217       0
# 1         0.124649      0.944706       0
# 2         0.124649     -0.190217       0
# ...            ...           ...     ...
# 4518     -0.263691     -0.190217       0
# 4519      0.606970      0.944706       0
# 4520      0.606970      0.944706       0
#
# [4521 rows x 14 columns]

# %% [markdown]
# ### 8. Delete correlated features

# %% [markdown]
# #### All Correlation

# %%
df_woe_uncorr, corr_matrix, to_drop = delete_correlated_features(data_woe, iv_values, inplace=False)
corr_matrix
# Out:
#               WOE_duration WOE_poutcome  WOE_month WOE_contact WOE_previous  \
# WOE_duration           NaN    0.0499845  0.0600007   0.0294938     0.027091
# WOE_poutcome           NaN          NaN     0.1959    0.166931      0.54967
# WOE_month              NaN          NaN        NaN    0.420767     0.178825
# ...                    ...          ...        ...         ...          ...
# WOE_pdays              NaN          NaN        NaN         NaN          NaN
# WOE_marital            NaN          NaN        NaN         NaN          NaN
# WOE_education          NaN          NaN        NaN         NaN          NaN
#
#                  WOE_job WOE_housing    WOE_age WOE_balance   WOE_loan  \
# WOE_duration   0.0455127   0.0193213  0.0344565   0.0538733  0.0228142
# WOE_poutcome   0.0548382   0.0957985  0.0684758   0.0542383  0.0402594
# WOE_month       0.118976    0.346633   0.158839    0.149603   0.131354
# ...                  ...         ...        ...         ...        ...
# WOE_pdays            NaN         NaN        NaN         NaN        NaN
# WOE_marital          NaN         NaN        NaN         NaN        NaN
# WOE_education        NaN         NaN        NaN         NaN        NaN
#
#                WOE_pdays WOE_marital WOE_education
# WOE_duration   0.0223509    0.020808     0.0249974
# WOE_poutcome    0.638745   0.0226195      0.027375
# WOE_month       0.228454   0.0624621       0.10649
# ...                  ...         ...           ...
# WOE_pdays            NaN   0.0165388     0.0175136
# WOE_marital          NaN         NaN      0.101271
# WOE_education        NaN         NaN           NaN
#
# [13 rows x 13 columns]

# %% [markdown]
# #### Inplace deletion

# %%
_, corr_matrix_inplace, _ = delete_correlated_features(data_woe, iv_values, inplace=True)
corr_matrix_inplace
# Out:
#               WOE_duration WOE_poutcome  WOE_month WOE_contact WOE_previous  \
# WOE_duration           NaN    0.0499845  0.0600007   0.0294938     0.027091
# WOE_poutcome           NaN          NaN        NaN    0.166931      0.54967
# WOE_month              NaN          NaN        NaN         NaN          NaN
# ...                    ...          ...        ...         ...          ...
# WOE_pdays              NaN          NaN        NaN         NaN          NaN
# WOE_marital            NaN          NaN        NaN         NaN          NaN
# WOE_education          NaN          NaN        NaN         NaN          NaN
#
#                  WOE_job WOE_housing    WOE_age WOE_balance   WOE_loan  \
# WOE_duration   0.0455127   0.0193213  0.0344565   0.0538733  0.0228142
# WOE_poutcome   0.0548382   0.0957985  0.0684758         NaN  0.0402594
# WOE_month            NaN         NaN        NaN         NaN        NaN
# ...                  ...         ...        ...         ...        ...
# WOE_pdays            NaN         NaN        NaN         NaN        NaN
# WOE_marital          NaN         NaN        NaN         NaN        NaN
# WOE_education        NaN         NaN        NaN         NaN        NaN
#
#                WOE_pdays WOE_marital WOE_education
# WOE_duration   0.0223509    0.020808     0.0249974
# WOE_poutcome    0.638745   0.0226195      0.027375
# WOE_month            NaN         NaN           NaN
# ...                  ...         ...           ...
# WOE_pdays            NaN         NaN           NaN
# WOE_marital          NaN         NaN           NaN
# WOE_education        NaN         NaN           NaN
#
# [13 rows x 13 columns]

# %% [markdown]
# #### Columns to drop

# %%
print('Features to drop', *to_drop, sep='\n')
# Out:
# Features to drop
# WOE_month
# WOE_balance
# WOE_contact
# WOE_previous
# WOE_job
# WOE_housing
# WOE_age
# WOE_pdays
# WOE_education

# %% [markdown]
# #### Final dataframe

# %%
df_woe_uncorr
# Out:
#       WOE_duration  WOE_loan  WOE_marital  WOE_poutcome  target
# 0        -1.807909  0.090598    -0.169697     -0.263691       0
# 1         0.152049 -0.674385    -0.169697      0.124649       0
# 2        -0.934434  0.090598     0.219950      0.124649       0
# ...            ...       ...          ...           ...     ...
# 4518     -0.934434  0.090598    -0.169697     -0.263691       0
# 4519     -1.807909  0.090598    -0.169697      0.606970       0
# 4520      0.152049 -0.674385     0.219950      0.606970       0
#
# [4521 rows x 5 columns]

# %% [markdown]
# # Full Pipeline

# %%
# %%time
df_woe_uncorr, corr_matrix, to_drop, iv_values = start_pipeline(data)
# Out:
# Wall time: 6.69 s

# %%
df_woe_uncorr
# Out:
#       WOE_duration  WOE_loan  WOE_marital  WOE_poutcome  target
# 0        -1.807909  0.090598    -0.169697     -0.263691       0
# 1         0.152049 -0.674385    -0.169697      0.124649       0
# 2        -0.934434  0.090598     0.219950      0.124649       0
# ...            ...       ...          ...           ...     ...
# 4518     -0.934434  0.090598    -0.169697     -0.263691       0
# 4519     -1.807909  0.090598    -0.169697      0.606970       0
# 4520      0.152049 -0.674385     0.219950      0.606970       0
#
# [4521 rows x 5 columns]

# %%
corr_matrix
# Out:
#               WOE_duration WOE_poutcome  WOE_month WOE_contact WOE_previous  \
# WOE_duration           NaN    0.0499845  0.0600007   0.0294938     0.027091
# WOE_poutcome           NaN          NaN        NaN    0.166931      0.54967
# WOE_month              NaN          NaN        NaN         NaN          NaN
# ...                    ...          ...        ...         ...          ...
# WOE_pdays              NaN          NaN        NaN         NaN          NaN
# WOE_marital            NaN          NaN        NaN         NaN          NaN
# WOE_education          NaN          NaN        NaN         NaN          NaN
#
#                  WOE_job WOE_housing    WOE_age WOE_balance   WOE_loan  \
# WOE_duration   0.0455127   0.0193213  0.0344565   0.0538733  0.0228142
# WOE_poutcome   0.0548382   0.0957985  0.0684758         NaN  0.0402594
# WOE_month            NaN         NaN        NaN         NaN        NaN
# ...                  ...         ...        ...         ...        ...
# WOE_pdays            NaN         NaN        NaN         NaN        NaN
# WOE_marital          NaN         NaN        NaN         NaN        NaN
# WOE_education        NaN         NaN        NaN         NaN        NaN
#
#                WOE_pdays WOE_marital WOE_education
# WOE_duration   0.0223509    0.020808     0.0249974
# WOE_poutcome    0.638745   0.0226195      0.027375
# WOE_month            NaN         NaN           NaN
# ...                  ...         ...           ...
# WOE_pdays            NaN         NaN           NaN
# WOE_marital          NaN         NaN           NaN
# WOE_education        NaN         NaN           NaN
#
# [13 rows x 13 columns]

# %%
to_drop
# Out:
# ['WOE_month',
#  'WOE_balance',
#  'WOE_contact',
#  'WOE_previous',
#  'WOE_job',
#  'WOE_housing',
#  'WOE_age',
#  'WOE_pdays',
#  'WOE_education']

# %%
iv_values.sort_values('IV', ascending=False)
# Out:
#     VAR_NAME            IV
# 6   duration  1.350591e+00
# 14  poutcome  4.618775e-01
# 12     month  3.795165e-01
# ..       ...           ...
# 4        day  4.129589e-03
# 5    default  1.644917e-05
# 2   campaign  2.786846e-18
#
# [16 rows x 2 columns]

# %% [markdown]
# ### Check on example with NULL

# %%
# %%time
data = pd.read_excel('data/bank_null.xlsx')
df_woe_uncorr, corr_matrix, to_drop, iv_values = start_pipeline(data)
# Out:
# Wall time: 7.04 s
