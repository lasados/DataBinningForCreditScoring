# %%
import sys
sys.path.append('../')

import pandas as pd
import numpy as np

from models.monotonic import *

# %%
pd.options.display.max_rows = 6

# %% [markdown]
# ### 1. Read data from file

# %%
data = pd.read_excel('../data/bank.xlsx')
data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# ### 2. Statistics collection from 'numeric' and 'categorical' feature

# %%
Y = (data['y'] == 'yes').astype(int).values
X_num = data['balance'].values
X_cat = data['job'].values
example_num = create_stats(X_num, Y)
example_cat = create_stats(X_cat, Y, 'categorical')

# %%
example_num
# Out:
#    VAR_NAME               BUCKET  MIN_VALUE  MAX_VALUE  COUNT  EVENT  \
# 0       VAR  (-3313.001, -162.0]    -3313.0     -162.0    227     25
# 1       VAR        (-162.0, 0.0]     -154.0        0.0    496     35
# 2       VAR          (0.0, 23.0]        1.0       23.0    190     20
# ..      ...                  ...        ...        ...    ...    ...
# 17      VAR     (3913.0, 6102.0]     3921.0     6102.0    226     38
# 18      VAR    (6102.0, 71188.0]     6145.0    71188.0    226     20
# 19      VAR                  NaN        NaN        NaN      0      0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.110132       202        0.889868        1.00         0.05050
# 1     0.070565       461        0.929435        1.40         0.11525
# 2     0.105263       170        0.894737        0.80         0.04250
# ..         ...       ...             ...         ...             ...
# 17    0.168142       188        0.831858        1.52         0.04700
# 18    0.088496       206        0.911504        0.80         0.05150
# 19    0.000000         0        0.000000        0.00         0.00000
#
#          WOE         IV
# 0  -2.985763  61.714854
# 1  -2.497116  61.714854
# 2  -2.935085  61.714854
# ..       ...        ...
# 17 -3.476297  61.714854
# 18 -2.743012  61.714854
# 19  0.000000  61.714854
#
# [20 rows x 13 columns]

# %%
example_cat
# Out:
#    VAR_NAME        BUCKET     MIN_VALUE     MAX_VALUE  COUNT  EVENT  \
# 0       VAR        admin.        admin.        admin.    478     58
# 1       VAR   blue-collar   blue-collar   blue-collar    946     69
# 2       VAR  entrepreneur  entrepreneur  entrepreneur    168     15
# ..      ...           ...           ...           ...    ...    ...
# 10      VAR    unemployed    unemployed    unemployed    128     13
# 11      VAR       unknown       unknown       unknown     38      7
# 12      VAR           NaN           NaN           NaN      0      0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.121339       420        0.878661    0.111324         0.10500
# 1     0.072939       877        0.927061    0.132438         0.21925
# 2     0.089286       153        0.910714    0.028791         0.03825
# ..         ...       ...             ...         ...             ...
# 10    0.101562       115        0.898437    0.024952         0.02875
# 11    0.184211        31        0.815789    0.013436         0.00775
# 12    0.000000         0        0.000000    0.000000         0.00000
#
#          WOE        IV
# 0  -0.058487  0.132516
# 1   0.504098  0.132516
# 2   0.284080  0.132516
# ..       ...       ...
# 10  0.141678  0.132516
# 11 -0.550168  0.132516
# 12  0.000000  0.132516
#
# [13 rows x 13 columns]

# %% [markdown]
# ### 3. Make 'numeric' data monotonic by WOE

# %%
monotonic_example_num = make_monotonic(example_num)
monotonic_example_num
# Out:
#   VAR_NAME               BUCKET  MIN_VALUE  MAX_VALUE   COUNT  EVENT  \
# 0      VAR  (-3313.001, -162.0]    -3313.0     -162.0   227.0   25.0
# 1      VAR    (-162.0, 71188.0]     -154.0    71188.0  4294.0  496.0
# 2      VAR                  NaN        NaN        NaN     0.0    0.0
#
#    EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT       WOE  \
# 0    0.110132     202.0        0.889868    1.000000          0.0505 -2.985763
# 1    0.115510    3798.0        0.884490    0.952015          0.9495 -0.002646
# 2    0.000000       0.0        0.000000    0.000000          0.0000  0.000000
#
#          IV
# 0  2.834989
# 1  2.834989
# 2  2.834989

# %% [markdown]
# ### 4. Use Algotithm of monotonic optimal binning for 'numeric' feature

# %%
optimal_example_num = monotone_optimal_binning(X_num, Y)
optimal_example_num
# Out:
#   VAR_NAME                   BUCKET  MIN_VALUE  MAX_VALUE   COUNT  EVENT  \
# 0      VAR  (-1000000000.0, 6102.0]    -3313.0     6102.0  4295.0  501.0
# 1      VAR   (6102.0, 1000000000.0]     6145.0    71188.0   226.0   20.0
# 2      VAR                      NaN        NaN        NaN     0.0    0.0
#
#    EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT       WOE  \
# 0    0.116647    3794.0        0.883353    0.961612          0.9485 -0.013730
# 1    0.088496     206.0        0.911504    0.038388          0.0515  0.293838
# 2    0.000000       0.0        0.000000    0.000000          0.0000  0.000000
#
#          IV
# 0  0.004033
# 1  0.004033
# 2  0.004033

# %% [markdown]
# ### 5. Apply previous steps for each feature

# %%
full_stats, iv_values = create_bins_df(data)
full_stats
# Out:
#     VAR_NAME                 BUCKET MIN_VALUE MAX_VALUE   COUNT  EVENT  \
# 0        age  (-1000000000.0, 29.0]        19        29   482.0   74.0
# 1        age   (29.0, 1000000000.0]        30        87  4039.0  447.0
# 2        age                    NaN       NaN       NaN     0.0    0.0
# ..       ...                    ...       ...       ...     ...    ...
# 67  poutcome                success   success   success   129.0   83.0
# 68  poutcome                unknown   unknown   unknown  3705.0  337.0
# 69  poutcome                    NaN       NaN       NaN     0.0    0.0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.153527     408.0        0.846473    0.142035          0.1020
# 1     0.110671    3592.0        0.889329    0.857965          0.8980
# 2     0.000000       0.0        0.000000    0.000000          0.0000
# ..         ...       ...             ...         ...             ...
# 67    0.643411      46.0        0.356589    0.159309          0.0115
# 68    0.090958    3368.0        0.909042    0.646833          0.8420
# 69    0.000000       0.0        0.000000    0.000000          0.0000
#
#          WOE        IV
# 0  -0.331095  0.015081
# 1   0.045606  0.015081
# 2   0.000000  0.015081
# ..       ...       ...
# 67 -2.628418  0.461878
# 68  0.263691  0.461878
# 69  0.000000  0.461878
#
# [70 rows x 13 columns]

# %%
iv_values
# Out:
#     VAR_NAME            IV
# 0        age  1.508105e-02
# 1    balance  4.032908e-03
# 2   campaign  4.456053e-02
# ..       ...           ...
# 13     pdays  2.786846e-18
# 14  poutcome  4.618775e-01
# 15  previous  2.786846e-18
#
# [16 rows x 2 columns]

# %% [markdown]
# ### 6. Cut of by Information Values

# %%
full_stats_cut, use_name_iv = cut_off_iv(full_stats, iv_values)
full_stats_cut
# Out:
#     VAR_NAME                 BUCKET MIN_VALUE MAX_VALUE   COUNT  EVENT  \
# 0        age  (-1000000000.0, 29.0]        19        29   482.0   74.0
# 1        age   (29.0, 1000000000.0]        30        87  4039.0  447.0
# 2        age                    NaN       NaN       NaN     0.0    0.0
# ..       ...                    ...       ...       ...     ...    ...
# 67  poutcome                success   success   success   129.0   83.0
# 68  poutcome                unknown   unknown   unknown  3705.0  337.0
# 69  poutcome                    NaN       NaN       NaN     0.0    0.0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.153527     408.0        0.846473    0.142035          0.1020
# 1     0.110671    3592.0        0.889329    0.857965          0.8980
# 2     0.000000       0.0        0.000000    0.000000          0.0000
# ..         ...       ...             ...         ...             ...
# 67    0.643411      46.0        0.356589    0.159309          0.0115
# 68    0.090958    3368.0        0.909042    0.646833          0.8420
# 69    0.000000       0.0        0.000000    0.000000          0.0000
#
#          WOE        IV
# 0  -0.331095  0.015081
# 1   0.045606  0.015081
# 2   0.000000  0.015081
# ..       ...       ...
# 67 -2.628418  0.461878
# 68  0.263691  0.461878
# 69  0.000000  0.461878
#
# [70 rows x 13 columns]

# %%
use_name_iv
# Out:
# array(['age', 'balance', 'campaign', 'contact', 'day', 'default',
#        'duration', 'education', 'housing', 'job', 'loan', 'marital',
#        'month', 'pdays', 'poutcome', 'previous'], dtype=object)

# %% [markdown]
# ### 7. Replace all features by WOE

# %%
data_woe = replace_by_woe_naive(data, full_stats_cut, use_name_iv)
data_woe
# Out:
#        WOE_age  WOE_balance  WOE_campaign  WOE_contact       WOE_day  \
# 0     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# 1     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# 2     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# ...        ...          ...           ...          ...           ...
# 4518  0.045606     -0.01373      0.592412    -0.252971  1.669384e-09
# 4519 -0.331095     -0.01373     -0.075498    -0.252971  1.669384e-09
# 4520  0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
#
#       WOE_default  WOE_duration  WOE_education  WOE_housing   WOE_job  \
# 0        0.000534  1.669384e-09       0.222811    -0.330234  0.141678
# 1        0.000534  1.669384e-09       0.091389     0.325551  0.261647
# 2        0.000534  1.669384e-09      -0.247403     0.325551 -0.182478
# ...           ...           ...            ...          ...       ...
# 4518     0.000534  1.669384e-09       0.091389    -0.330234  0.072278
# 4519     0.000534  1.669384e-09       0.091389    -0.330234  0.504098
# 4520     0.000534  1.669384e-09      -0.247403     0.325551  0.284080
#
#       WOE_loan  WOE_marital  WOE_month     WOE_pdays  WOE_poutcome  \
# 0    -0.090598     0.169697  -1.887938  1.669384e-09      0.263691
# 1     0.674385     0.169697   0.603057  1.669384e-09     -0.124649
# 2    -0.090598    -0.219950  -0.595584  1.669384e-09     -0.124649
# ...        ...          ...        ...           ...           ...
# 4518 -0.090598     0.169697  -0.090582  1.669384e-09      0.263691
# 4519 -0.090598     0.169697  -0.460942  1.669384e-09     -0.606970
# 4520  0.674385    -0.219950  -0.595584  1.669384e-09     -0.606970
#
#       WOE_previous  target
# 0     1.669384e-09       0
# 1     1.669384e-09       0
# 2     1.669384e-09       0
# ...            ...     ...
# 4518  1.669384e-09       0
# 4519  1.669384e-09       0
# 4520  1.669384e-09       0
#
# [4521 rows x 17 columns]

# %% [markdown]
# ### 8. Delete correlated features

# %% [markdown]
# #### All Correlation

# %%
df_woe_uncorr, corr_matrix, to_drop = delete_correlated_features(data_woe, iv_values, inplace=False)
corr_matrix
# Out:
#              WOE_poutcome WOE_month WOE_contact    WOE_job WOE_housing  \
# WOE_poutcome          NaN    0.1959    0.166931  0.0548382   0.0957985
# WOE_month             NaN       NaN    0.420767   0.118976    0.346633
# WOE_contact           NaN       NaN         NaN   0.129234    0.154812
# ...                   ...       ...         ...        ...         ...
# WOE_duration          NaN       NaN         NaN        NaN         NaN
# WOE_pdays             NaN       NaN         NaN        NaN         NaN
# WOE_previous          NaN       NaN         NaN        NaN         NaN
#
#                 WOE_loan WOE_campaign WOE_marital WOE_education    WOE_age  \
# WOE_poutcome   0.0402594    0.0672918   0.0226195      0.027375  0.0279067
# WOE_month       0.131354     0.148541   0.0624621       0.10649    0.12235
# WOE_contact   0.00597174    0.0115889   0.0466537      0.104116   0.014422
# ...                  ...          ...         ...           ...        ...
# WOE_duration         NaN          NaN         NaN           NaN        NaN
# WOE_pdays            NaN          NaN         NaN           NaN        NaN
# WOE_previous         NaN          NaN         NaN           NaN        NaN
#
#              WOE_balance WOE_default WOE_day WOE_duration WOE_pdays  \
# WOE_poutcome   0.0276973   0.0333562       0            0         0
# WOE_month        0.10517   0.0438847       0            0         0
# WOE_contact    0.0246698   0.0167352       0            0         0
# ...                  ...         ...     ...          ...       ...
# WOE_duration         NaN         NaN     NaN          NaN         0
# WOE_pdays            NaN         NaN     NaN          NaN       NaN
# WOE_previous         NaN         NaN     NaN          NaN       NaN
#
#              WOE_previous
# WOE_poutcome            0
# WOE_month               0
# WOE_contact             0
# ...                   ...
# WOE_duration            0
# WOE_pdays               0
# WOE_previous          NaN
#
# [16 rows x 16 columns]

# %% [markdown]
# #### Inplace deletion

# %%
_, corr_matrix_inplace, _ = delete_correlated_features(data_woe, iv_values, inplace=True)
corr_matrix_inplace
# Out:
#              WOE_poutcome WOE_month WOE_contact    WOE_job WOE_housing  \
# WOE_poutcome          NaN    0.1959    0.166931  0.0548382   0.0957985
# WOE_month             NaN       NaN    0.420767   0.118976    0.346633
# WOE_contact           NaN       NaN         NaN   0.129234    0.154812
# ...                   ...       ...         ...        ...         ...
# WOE_duration          NaN       NaN         NaN        NaN         NaN
# WOE_pdays             NaN       NaN         NaN        NaN         NaN
# WOE_previous          NaN       NaN         NaN        NaN         NaN
#
#                 WOE_loan WOE_campaign WOE_marital WOE_education    WOE_age  \
# WOE_poutcome   0.0402594    0.0672918   0.0226195      0.027375  0.0279067
# WOE_month       0.131354     0.148541   0.0624621       0.10649    0.12235
# WOE_contact   0.00597174    0.0115889   0.0466537      0.104116   0.014422
# ...                  ...          ...         ...           ...        ...
# WOE_duration         NaN          NaN         NaN           NaN        NaN
# WOE_pdays            NaN          NaN         NaN           NaN        NaN
# WOE_previous         NaN          NaN         NaN           NaN        NaN
#
#              WOE_balance WOE_default WOE_day WOE_duration WOE_pdays  \
# WOE_poutcome   0.0276973   0.0333562       0            0         0
# WOE_month        0.10517   0.0438847       0            0         0
# WOE_contact    0.0246698   0.0167352       0            0         0
# ...                  ...         ...     ...          ...       ...
# WOE_duration         NaN         NaN     NaN          NaN         0
# WOE_pdays            NaN         NaN     NaN          NaN       NaN
# WOE_previous         NaN         NaN     NaN          NaN       NaN
#
#              WOE_previous
# WOE_poutcome            0
# WOE_month               0
# WOE_contact             0
# ...                   ...
# WOE_duration            0
# WOE_pdays               0
# WOE_previous          NaN
#
# [16 rows x 16 columns]

# %% [markdown]
# #### Columns to drop

# %%
print('Features to drop', *to_drop, sep='\n')
# Out:
# Features to drop

# %% [markdown]
# #### Final dataframe

# %%
df_woe_uncorr
# Out:
#        WOE_age  WOE_balance  WOE_campaign  WOE_contact       WOE_day  \
# 0     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# 1     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# 2     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# ...        ...          ...           ...          ...           ...
# 4518  0.045606     -0.01373      0.592412    -0.252971  1.669384e-09
# 4519 -0.331095     -0.01373     -0.075498    -0.252971  1.669384e-09
# 4520  0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
#
#       WOE_default  WOE_duration  WOE_education  WOE_housing   WOE_job  \
# 0        0.000534  1.669384e-09       0.222811    -0.330234  0.141678
# 1        0.000534  1.669384e-09       0.091389     0.325551  0.261647
# 2        0.000534  1.669384e-09      -0.247403     0.325551 -0.182478
# ...           ...           ...            ...          ...       ...
# 4518     0.000534  1.669384e-09       0.091389    -0.330234  0.072278
# 4519     0.000534  1.669384e-09       0.091389    -0.330234  0.504098
# 4520     0.000534  1.669384e-09      -0.247403     0.325551  0.284080
#
#       WOE_loan  WOE_marital  WOE_month     WOE_pdays  WOE_poutcome  \
# 0    -0.090598     0.169697  -1.887938  1.669384e-09      0.263691
# 1     0.674385     0.169697   0.603057  1.669384e-09     -0.124649
# 2    -0.090598    -0.219950  -0.595584  1.669384e-09     -0.124649
# ...        ...          ...        ...           ...           ...
# 4518 -0.090598     0.169697  -0.090582  1.669384e-09      0.263691
# 4519 -0.090598     0.169697  -0.460942  1.669384e-09     -0.606970
# 4520  0.674385    -0.219950  -0.595584  1.669384e-09     -0.606970
#
#       WOE_previous  target
# 0     1.669384e-09       0
# 1     1.669384e-09       0
# 2     1.669384e-09       0
# ...            ...     ...
# 4518  1.669384e-09       0
# 4519  1.669384e-09       0
# 4520  1.669384e-09       0
#
# [4521 rows x 17 columns]

# %% [markdown]
# # Full Pipeline

# %%
# %%time
df_woe_uncorr, corr_matrix, to_drop, iv_values, full_stats, use_name_iv = start_pipeline(data)
# Out:
# Replace on WOE optimal = 0.028 seconds
# Creating full stats = 2.153 seconds
# Cutting of by IV = 0.002 seconds
# Delete correlations = 0.965 seconds
# Wall time: 3.15 s

# %%
df_woe_uncorr
# Out:
#        WOE_age  WOE_balance  WOE_campaign  WOE_contact       WOE_day  \
# 0     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# 1     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# 2     0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
# ...        ...          ...           ...          ...           ...
# 4518  0.045606     -0.01373      0.592412    -0.252971  1.669384e-09
# 4519 -0.331095     -0.01373     -0.075498    -0.252971  1.669384e-09
# 4520  0.045606     -0.01373     -0.075498    -0.252971  1.669384e-09
#
#       WOE_default  WOE_duration  WOE_education  WOE_housing   WOE_job  \
# 0        0.000534  1.669384e-09       0.222811    -0.330234  0.141678
# 1        0.000534  1.669384e-09       0.091389     0.325551  0.261647
# 2        0.000534  1.669384e-09      -0.247403     0.325551 -0.182478
# ...           ...           ...            ...          ...       ...
# 4518     0.000534  1.669384e-09       0.091389    -0.330234  0.072278
# 4519     0.000534  1.669384e-09       0.091389    -0.330234  0.504098
# 4520     0.000534  1.669384e-09      -0.247403     0.325551  0.284080
#
#       WOE_loan  WOE_marital  WOE_month     WOE_pdays  WOE_poutcome  \
# 0    -0.090598     0.169697  -1.887938  1.669384e-09      0.263691
# 1     0.674385     0.169697   0.603057  1.669384e-09     -0.124649
# 2    -0.090598    -0.219950  -0.595584  1.669384e-09     -0.124649
# ...        ...          ...        ...           ...           ...
# 4518 -0.090598     0.169697  -0.090582  1.669384e-09      0.263691
# 4519 -0.090598     0.169697  -0.460942  1.669384e-09     -0.606970
# 4520  0.674385    -0.219950  -0.595584  1.669384e-09     -0.606970
#
#       WOE_previous  target
# 0     1.669384e-09       0
# 1     1.669384e-09       0
# 2     1.669384e-09       0
# ...            ...     ...
# 4518  1.669384e-09       0
# 4519  1.669384e-09       0
# 4520  1.669384e-09       0
#
# [4521 rows x 17 columns]

# %%
corr_matrix
# Out:
#              WOE_poutcome WOE_month WOE_contact    WOE_job WOE_housing  \
# WOE_poutcome          NaN    0.1959    0.166931  0.0548382   0.0957985
# WOE_month             NaN       NaN    0.420767   0.118976    0.346633
# WOE_contact           NaN       NaN         NaN   0.129234    0.154812
# ...                   ...       ...         ...        ...         ...
# WOE_duration          NaN       NaN         NaN        NaN         NaN
# WOE_pdays             NaN       NaN         NaN        NaN         NaN
# WOE_previous          NaN       NaN         NaN        NaN         NaN
#
#                 WOE_loan WOE_campaign WOE_marital WOE_education    WOE_age  \
# WOE_poutcome   0.0402594    0.0672918   0.0226195      0.027375  0.0279067
# WOE_month       0.131354     0.148541   0.0624621       0.10649    0.12235
# WOE_contact   0.00597174    0.0115889   0.0466537      0.104116   0.014422
# ...                  ...          ...         ...           ...        ...
# WOE_duration         NaN          NaN         NaN           NaN        NaN
# WOE_pdays            NaN          NaN         NaN           NaN        NaN
# WOE_previous         NaN          NaN         NaN           NaN        NaN
#
#              WOE_balance WOE_default WOE_day WOE_duration WOE_pdays  \
# WOE_poutcome   0.0276973   0.0333562       0            0         0
# WOE_month        0.10517   0.0438847       0            0         0
# WOE_contact    0.0246698   0.0167352       0            0         0
# ...                  ...         ...     ...          ...       ...
# WOE_duration         NaN         NaN     NaN          NaN         0
# WOE_pdays            NaN         NaN     NaN          NaN       NaN
# WOE_previous         NaN         NaN     NaN          NaN       NaN
#
#              WOE_previous
# WOE_poutcome            0
# WOE_month               0
# WOE_contact             0
# ...                   ...
# WOE_duration            0
# WOE_pdays               0
# WOE_previous          NaN
#
# [16 rows x 16 columns]

# %%
to_drop
# Out:
# []

# %%
iv_values.sort_values('IV', ascending=False)
# Out:
#     VAR_NAME            IV
# 14  poutcome  4.618775e-01
# 12     month  3.795165e-01
# 3    contact  2.477613e-01
# ..       ...           ...
# 6   duration  2.786846e-18
# 13     pdays  2.786846e-18
# 15  previous  2.786846e-18
#
# [16 rows x 2 columns]

# %%
full_stats
# Out:
#     VAR_NAME                 BUCKET MIN_VALUE MAX_VALUE   COUNT  EVENT  \
# 0        age  (-1000000000.0, 29.0]        19        29   482.0   74.0
# 1        age   (29.0, 1000000000.0]        30        87  4039.0  447.0
# 2        age                    NaN       NaN       NaN     0.0    0.0
# ..       ...                    ...       ...       ...     ...    ...
# 67  poutcome                success   success   success   129.0   83.0
# 68  poutcome                unknown   unknown   unknown  3705.0  337.0
# 69  poutcome                    NaN       NaN       NaN     0.0    0.0
#
#     EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0     0.153527     408.0        0.846473    0.142035          0.1020
# 1     0.110671    3592.0        0.889329    0.857965          0.8980
# 2     0.000000       0.0        0.000000    0.000000          0.0000
# ..         ...       ...             ...         ...             ...
# 67    0.643411      46.0        0.356589    0.159309          0.0115
# 68    0.090958    3368.0        0.909042    0.646833          0.8420
# 69    0.000000       0.0        0.000000    0.000000          0.0000
#
#          WOE        IV
# 0  -0.331095  0.015081
# 1   0.045606  0.015081
# 2   0.000000  0.015081
# ..       ...       ...
# 67 -2.628418  0.461878
# 68  0.263691  0.461878
# 69  0.000000  0.461878
#
# [70 rows x 13 columns]

# %% [markdown]
# ### Check on example with NULL

# %%
# %%time
data = pd.read_excel('../data/bank_null.xlsx')
df_woe_uncorr, corr_matrix, to_drop, iv_values, full_stats, use_names = start_pipeline(data)
# Out:
# Replace on WOE optimal = 0.027 seconds
# Creating full stats = 2.146 seconds
# Cutting of by IV = 0.002 seconds
# Delete correlations = 1.066 seconds
# Wall time: 3.86 s
